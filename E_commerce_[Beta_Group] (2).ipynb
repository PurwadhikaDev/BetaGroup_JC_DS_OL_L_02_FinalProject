# %% [markdown]
# # E Commerce Analysis: Customer Churn
# ### Created By : Beta Team JCDSOLL02

# %% [markdown]
# # **Business Problem Understanding**

# %% [markdown]
# **Context**
# Sebuah perusahaan e-commerce ingin meningkatkan retensi pelanggan dan mengurangi jumlah pelanggan yang berhenti menggunakan layanan (customer churn). Seiring dengan meningkatnya persaingan di industri e-commerce, memahami perilaku dan karakteristik pelanggan menjadi hal yang krusial agar perusahaan dapat mengambil keputusan bisnis yang lebih tepat.
#
# Data yang digunakan dalam analisis ini merupakan dataset publik bertajuk "E-Commerce Customer Churn Analysis and Prediction" yang berasal dari pasar India. Hal ini teridentifikasi dari penggunaan metode pembayaran spesifik seperti UPI (Unified Payments Interface) dan klasifikasi wilayah berdasarkan City Tier (Tier 1, 2, dan 3) yang merupakan standar klasifikasi perkotaan di India. Data ini mencakup periode aktivitas pelanggan sekitar tahun 2019 hingga 2021, yang mencerminkan dinamika belanja online pada masa tersebut.
#
# Perusahaan memiliki data historis pelanggan yang mencakup informasi demografi, perilaku penggunaan aplikasi, kebiasaan transaksi, preferensi pembayaran, serta interaksi pelanggan dengan layanan (seperti komplain dan tingkat kepuasan). Namun, belum semua informasi tersebut dimanfaatkan secara optimal untuk memprediksi pelanggan yang berpotensi churn.
#
# Dengan memanfaatkan data ini, perusahaan ingin mengetahui pelanggan mana yang berisiko tinggi untuk churn sehingga dapat dilakukan tindakan preventif seperti penawaran promosi, peningkatan layanan, atau pendekatan personalisasi lainnya. Hal ini diharapkan dapat mengurangi biaya akuisisi pelanggan baru serta meningkatkan loyalitas pelanggan yang sudah ada.
#
# Target :
#
# 0 : Pelanggan tidak churn (masih aktif menggunakan layanan e-commerce)
#
# 1 : Pelanggan churn (berhenti atau tidak lagi aktif menggunakan layanan e-commerce)

# %% [markdown]
# **Problem Statement :**
#
# Customer churn merupakan salah satu tantangan utama dalam bisnis e-commerce karena berdampak langsung pada pendapatan dan pertumbuhan perusahaan. Jika perusahaan memperlakukan seluruh pelanggan dengan pendekatan yang sama tanpa mengetahui siapa yang berpotensi churn, maka upaya retensi yang dilakukan bisa menjadi tidak efektif dan menghabiskan biaya yang besar.
#
# Perusahaan telah mengeluarkan berbagai biaya untuk menarik dan melayani pelanggan, seperti promosi, cashback, kupon, dan peningkatan layanan. Namun, biaya tersebut akan menjadi sia-sia apabila pelanggan yang menerima berbagai benefit tersebut tetap berhenti menggunakan layanan e-commerce. Oleh karena itu, perusahaan perlu mengetahui pelanggan mana yang berisiko churn agar strategi retensi dapat dilakukan secara lebih terarah dan efisien.
#
# **Goals :**
#
# Berdasarkan permasalahan tersebut, perusahaan ingin memiliki kemampuan untuk memprediksi kemungkinan seorang pelanggan akan mengalami churn atau tidak, sehingga perusahaan dapat memfokuskan upaya retensi pada pelanggan yang benar-benar berisiko tinggi untuk churn.
#
# Selain itu, perusahaan juga ingin mengetahui faktor atau variabel apa saja yang paling memengaruhi keputusan pelanggan untuk berhenti menggunakan layanan e-commerce. Dengan memahami faktor-faktor tersebut, perusahaan dapat merancang strategi bisnis yang lebih baik, seperti peningkatan kualitas layanan, optimalisasi promosi, dan personalisasi pengalaman pelanggan guna menurunkan tingkat churn.
#
# **Analytic Approach :**
#
# Analisis akan dilakukan dengan mengeksplorasi data pelanggan e-commerce untuk menemukan pola dan karakteristik yang membedakan pelanggan yang churn dan yang tidak churn.
#
# Selanjutnya, akan dibangun model klasifikasi menggunakan variabel-variabel yang tersedia dalam dataset untuk memprediksi probabilitas seorang pelanggan akan churn atau tidak. Model ini diharapkan dapat membantu perusahaan dalam pengambilan keputusan berbasis data terkait strategi retensi pelanggan.

# %% [markdown]
# **Metric Evaluation**

# %% [markdown]
# <img src="https://drive.google.com/uc?export=view&id=1Pn6QKBwJekcQ3vK5OCNQ3IfiNwvPW8gp" alt="Confusion Matrix Churn">

# %% [markdown]
# Type 1 error : False Positive
# Model memprediksi pelanggan akan churn, padahal sebenarnya tidak churn.
#
# **Konsekuensi**: Perusahaan mengeluarkan biaya retensi yang tidak perlu, seperti pemberian diskon, cashback, kupon, atau intervensi layanan khusus kepada pelanggan yang sebenarnya masih loyal. Hal ini menyebabkan pemborosan biaya pemasaran dan sumber daya operasional.
#
# Type 2 error : False Negative
# Model memprediksi pelanggan tidak churn, padahal sebenarnya churn.
#
# **Konsekuensi**: Perusahaan kehilangan pelanggan yang seharusnya dapat dipertahankan. Ini berdampak pada hilangnya pendapatan jangka panjang serta meningkatnya biaya akuisisi pelanggan baru untuk menggantikan pelanggan yang churn.
#
# **Pertimbangan Metrik:** Berdasarkan konsekuensinya, fokus utama model adalah menekan kehilangan pelanggan (meminimalkan False Negative) tanpa mengabaikan efisiensi biaya promosi (meminimalkan False Positive). Oleh karena itu, kita perlu menyeimbangkan Precision dan Recall melalui metrik F1-Score.
#
# Namun, dalam proyek ini metrik utama yang digunakan adalah ROC-AUC untuk melihat kemampuan model dalam membedakan kelas secara keseluruhan. Meskipun ROC-AUC bisa menjadi kurang akurat pada data yang imbalanced seperti dataset ini, metrik ini tetap digunakan sebagai standar awal evaluasi performa model.

# %% [markdown]
# # **Analisis Customer Churn E-commerce Menggunakan Machine Learning**
#
# * Customer churn merupakan tantangan yang sangat penting dalam industri e-commerce, karena mempertahankan pelanggan yang sudah ada umumnya jauh lebih hemat biaya dibandingkan dengan memperoleh pelanggan baru. Dataset ini berfokus pada pemahaman perilaku pelanggan, preferensi, serta pola keterlibatan (engagement) untuk mengidentifikasi faktor-faktor yang memengaruhi terjadinya churn. Data yang digunakan mencakup informasi demografis, riwayat transaksi, perilaku penggunaan aplikasi, tingkat kepuasan pelanggan, serta interaksi terkait layanan. Dengan menerapkan teknik machine learning pada data ini, perusahaan dapat memprediksi kemungkinan customer churn, memperoleh insight yang dapat ditindaklanjuti, dan merancang strategi retensi yang lebih tepat sasaran guna meningkatkan loyalitas pelanggan serta profitabilitas jangka panjang.
#
# * Sumber Dataset:
#   https://www.kaggle.com/datasets/ankitverma2010/ecommerce-customer-churn-analysis-and-prediction/data

# %%
# improt the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from tabulate import tabulate


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load the Dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ankitverma2010/ecommerce-customer-churn-analysis-and-prediction")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'ecommerce-customer-churn-analysis-and-prediction' dataset.
# Path to dataset files: /kaggle/input/ecommerce-customer-churn-analysis-and-prediction

# %% [markdown]
# ## **Data Understanding & Exploration**

# %%
def explore_dataset(df, data_filename=None):
    """
    In explore_dataset function we are doing all the things that given below:
    - checking shape of dataset
    - checking column names that exist in dataset
    - checking null values
    - checking overall information about dataset using info() method
    - checking dtypes of columns
    """
    print("="*100)
    print("\t\t\tEDA Dataset: {}".format(data_filename))
    print("="*100)

    print("Total Rows: {}".format(df.shape[0]))
    print("\nTotal Columns: {}".format(df.shape[1]))
    print("="*100)
    print("\nColumns: {}".format(df.columns.tolist()))
    print("="*100)
    print("\nTotal Null Values: {}".format(df.isnull().sum().sum()))
    print("\t\tOverall Null Values in Features\n")
    print(df.isnull().sum())
    print("="*100)
    print("Any Duplicated Values: {}".format(df.duplicated().any()))
    print("="*100)
    print("\t\tOverall Information about Dataset\n")
    print(df.info())
    print("="*100)
    print("\t\tDtype of all Columns\n")
    print(df.dtypes)
    print()

# %%
path
# Out:
# '/kaggle/input/ecommerce-customer-churn-analysis-and-prediction'

# %%
filename = f'{path}/E Commerce Dataset.xlsx'
df = pd.read_excel(filename, sheet_name='E Comm')

# %%
# lets check the information of dataset
explore_dataset(df,filename)
# Out:
# ...
# 			EDA Dataset: /kaggle/input/ecommerce-customer-churn-analysis-and-prediction/E Commerce Dataset.xlsx
# ...
# Total Rows: 5630
#
# Total Columns: 20
# ...
#
# Columns: ['CustomerID', 'Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier', 'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp', 'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore', 'MaritalStatus', 'NumberOfAddress', 'Complain', 'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount']
# ...
#
# Total Null Values: 1856
# 		Overall Null Values in Features
#
# CustomerID                       0
# Churn                            0
# Tenure                         264
# PreferredLoginDevice             0
# CityTier                         0
# WarehouseToHome                251
# PreferredPaymentMode             0
# Gender                           0
# HourSpendOnApp                 255
# NumberOfDeviceRegistered         0
# PreferedOrderCat                 0
# ...

# %% [markdown]
# * Dataset ini memiliki total **5.630 baris** dan **20 kolom**.
#
# * Terdapat **1.856 nilai null** di seluruh dataset, yang sebagian besar berada pada fitur numerik seperti
#   `Tenure, WarehouseToHome, HourSpendOnApp, OrderAmountHikeFromLastYear, CouponUsed, OrderCount, dan DaySinceLastOrder`.
#
# * Tidak ditemukan **data duplikat** dalam dataset, sehingga konsistensi data tetap terjaga.
#
# * Dataset ini terdiri dari **berbagai tipe data**, yaitu:
#   * **8 fitur float** (float64)
#   * **7 fitur integer** (int64)
#   * **5 fitur kategorikal** (object)
#
# * Variabel kategorikal meliputi
#   `PreferredLoginDevice, PreferredPaymentMode, Gender, PreferedOrderCat, dan MaritalStatus`.
#
# * Keberadaan atribut numerik dan kategorikal secara bersamaan menjadikan dataset ini **sangat sesuai untuk analisis dan prediksi customer churn**, dengan tahapan preprocessing yang diperlukan seperti **penanganan missing values** dan **encoding variabel kategorikal**.

# %%
df.head()
# Out:
#    CustomerID  Churn  Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0       50001      1     4.0         Mobile Phone         3              6.0
# 1       50002      1     NaN                Phone         1              8.0
# 2       50003      1     NaN                Phone         1             30.0
# 3       50004      1     0.0                Phone         3             15.0
# 4       50005      1     0.0                Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female             3.0                         3
# 1                  UPI    Male             3.0                         4
# 2           Debit Card    Male             2.0                         4
# 3           Debit Card    Male             2.0                         4
# 4                   CC    Male             NaN                         3
#
# ...

# %%
# lets ensure data types match
data_types = df.dtypes.to_frame().rename(columns={0:'dtypes'})
print(tabulate(data_types, headers = 'keys', tablefmt = 'psql'))
# Out:
# +-----------------------------+----------+
# |                             | dtypes   |
# |-----------------------------+----------|
# | CustomerID                  | int64    |
# | Churn                       | int64    |
# | Tenure                      | float64  |
# | PreferredLoginDevice        | object   |
# | CityTier                    | int64    |
# | WarehouseToHome             | float64  |
# | PreferredPaymentMode        | object   |
# | Gender                      | object   |
# | HourSpendOnApp              | float64  |
# | NumberOfDeviceRegistered    | int64    |
# | PreferedOrderCat            | object   |
# | SatisfactionScore           | int64    |
# | MaritalStatus               | object   |
# | NumberOfAddress             | int64    |
# | Complain                    | int64    |
# | OrderAmountHikeFromlastYear | float64  |
# | CouponUsed                  | float64  |
# | OrderCount                  | float64  |
# | DaySinceLastOrder           | float64  |
# ...

# %% [markdown]
# * Setiap kolom telah diberikan **tipe data yang sesuai dan konsisten** berdasarkan karakteristiknya (integer, float, atau kategorikal).
#
# * Variabel numerik seperti `Tenure, WarehouseToHome, OrderCount, dan CashbackAmount` telah **disimpan dengan benar sebagai float64**.
#
# * Variabel diskrit dan berbasis flag seperti `CustomerID, Churn, CityTier, dan Complain` telah **disimpan dengan benar sebagai int64**.
#
# * Atribut kategorikal termasuk `PreferredLoginDevice, PreferredPaymentMode, Gender, PreferedOrderCat, dan MaritalStatus` telah **disimpan dengan tepat sebagai tipe object**.
#
# * Secara keseluruhan, kami memastikan bahwa **seluruh tipe data fitur telah sesuai dengan representasi yang dimaksud**, sehingga dataset siap untuk tahap **preprocessing lanjutan dan pemodelan machine learning**.

# %%
# lets Check for and address any inconsistent values in categorical columns.
def check_categorical_unique_values(categorical_columns):
    for col in categorical_columns:
        unique_values = df[col].unique()
        value_counts = df[col].value_counts()
        print(f">> Unique values in column '{col}':")
        for value in unique_values:
            count = value_counts.get(value, 0)
            print(f"\t| {value}: {count} occurrences")

# %%
categortical_cols = df.select_dtypes(include=['object']).columns.tolist() # lets fetch the categorical columns
categortical_cols
# Out:
# ['PreferredLoginDevice',
#  'PreferredPaymentMode',
#  'Gender',
#  'PreferedOrderCat',
#  'MaritalStatus']

# %%
check_categorical_unique_values(categortical_cols)
# Out:
# >> Unique values in column 'PreferredLoginDevice':
# 	| Mobile Phone: 2765 occurrences
# 	| Phone: 1231 occurrences
# 	| Computer: 1634 occurrences
# >> Unique values in column 'PreferredPaymentMode':
# 	| Debit Card: 2314 occurrences
# 	| UPI: 414 occurrences
# 	| CC: 273 occurrences
# 	| Cash on Delivery: 149 occurrences
# 	| E wallet: 614 occurrences
# 	| COD: 365 occurrences
# 	| Credit Card: 1501 occurrences
# >> Unique values in column 'Gender':
# 	| Female: 2246 occurrences
# 	| Male: 3384 occurrences
# >> Unique values in column 'PreferedOrderCat':
# 	| Laptop & Accessory: 2050 occurrences
# 	| Mobile: 809 occurrences
# 	| Mobile Phone: 1271 occurrences
# 	| Others: 264 occurrences
# 	| Fashion: 826 occurrences
# 	| Grocery: 410 occurrences
# >> Unique values in column 'MaritalStatus':
# 	| Single: 1796 occurrences
# 	| Divorced: 848 occurrences
# 	| Married: 2986 occurrences

# %% [markdown]
# * Analisis fitur kategorikal menunjukkan adanya **ketidakkonsistenan dalam penamaan dan representasi kategori** pada beberapa kolom.
#
# * Pada `PreferredLoginDevice`, kategori yang memiliki makna sama seperti “Mobile Phone” dan “Phone” merepresentasikan konsep yang sama, namun diperlakukan sebagai nilai yang berbeda, sehingga dapat menimbulkan noise dalam analisis.
#
# * Pada `PreferredPaymentMode`, kategori yang redundan seperti “Cash on Delivery” dan “COD”, serta “CC” dan “Credit Card”, menunjukkan pelabelan yang tidak konsisten dan perlu distandarisasi.
#
# * Pada `PreferedOrderCat`, kategori yang tumpang tindih seperti “Mobile” dan “Mobile Phone” mencerminkan duplikasi makna (semantic duplication), yang dapat berdampak negatif pada performa model jika tidak ditangani.
#
# * Fitur `Gender` dan `MaritalStatus` terlihat konsisten, tanpa adanya duplikasi atau masalah pelabelan yang jelas.
#
# * Ketidakkonsistenan ini menegaskan pentingnya **data cleaning dan normalisasi kategori** (misalnya menggabungkan label yang ekuivalen) sebelum melakukan encoding variabel kategorikal untuk model machine learning.

# %% [markdown]
# ## **Data Cleaning & Analysis**

# %%
# Fix the inconsistency between the features
df['PreferredLoginDevice'] = df['PreferredLoginDevice'].replace({
    'Phone': 'Mobile Phone'
})
df['PreferredPaymentMode'] = df['PreferredPaymentMode'].replace({
    'COD': 'Cash on Delivery',
    'CC': 'Credit Card'
})
df['PreferedOrderCat'] = df['PreferedOrderCat'].replace({
    'Mobile': 'Mobile Phone'
})

# %%
# Verify cleaned categories
print("PreferredLoginDevice:", df['PreferredLoginDevice'].unique())
print("PreferredPaymentMode:", df['PreferredPaymentMode'].unique())
print("PreferedOrderCat:", df['PreferedOrderCat'].unique())
# Out:
# PreferredLoginDevice: ['Mobile Phone' 'Computer']
# PreferredPaymentMode: ['Debit Card' 'UPI' 'Credit Card' 'Cash on Delivery' 'E wallet']
# PreferedOrderCat: ['Laptop & Accessory' 'Mobile Phone' 'Others' 'Fashion' 'Grocery']

# %%
# Calculate the count of unique values for each column
unique_value_counts = df.nunique()
unique_counts_df = pd.DataFrame({'Column': unique_value_counts.index, 'Unique Count': unique_value_counts.values})
print(tabulate(unique_counts_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+-----------------------------+----------------+
# |    | Column                      |   Unique Count |
# |----+-----------------------------+----------------|
# |  0 | CustomerID                  |           5630 |
# |  1 | Churn                       |              2 |
# |  2 | Tenure                      |             36 |
# |  3 | PreferredLoginDevice        |              2 |
# |  4 | CityTier                    |              3 |
# |  5 | WarehouseToHome             |             34 |
# |  6 | PreferredPaymentMode        |              5 |
# |  7 | Gender                      |              2 |
# |  8 | HourSpendOnApp              |              6 |
# |  9 | NumberOfDeviceRegistered    |              6 |
# | 10 | PreferedOrderCat            |              5 |
# | 11 | SatisfactionScore           |              5 |
# | 12 | MaritalStatus               |              3 |
# | 13 | NumberOfAddress             |             15 |
# ...

# %% [markdown]
# * Analisis nilai unik menunjukkan bahwa `CustomerID` memiliki **5.630 nilai unik**, yang menegaskan bahwa setiap baris merepresentasikan **pelanggan yang berbeda**.
#
# * Variabel target `Churn` memiliki **2 kelas unik**, sehingga permasalahan ini termasuk **binary classification problem**.
#
# * Beberapa fitur kategorikal seperti
#   `PreferredLoginDevice (2), PreferredPaymentMode (5), Gender (2), PreferedOrderCat (5), dan MaritalStatus (3)`
#   memiliki jumlah kategori yang terbatas, sehingga **sesuai untuk teknik encoding** seperti *one-hot encoding* atau *label encoding*.
#
# * Fitur numerik ordinal dan diskrit seperti
#   `CityTier (3), SatisfactionScore (5), NumberOfDeviceRegistered (6), dan HourSpendOnApp (6)`
#   menunjukkan variasi yang terkontrol, yang mengindikasikan adanya **pola perilaku pelanggan yang terstruktur**.
#
# * Fitur numerik kontinu seperti
#   `Tenure, WarehouseToHome, OrderAmountHikeFromLastYear, CouponUsed, OrderCount, dan DaySinceLastOrder`
#   memiliki jumlah nilai unik yang sedang, sehingga **berpotensi mendapatkan manfaat dari proses scaling atau normalization**.
#
# * `CashbackAmount` memiliki jumlah nilai unik yang sangat tinggi (**2.586**), yang menunjukkan bahwa fitur ini bersifat **sangat kontinu** dan kemungkinan memiliki **pengaruh kuat terhadap prediksi customer churn**.
#
# * Secara keseluruhan, distribusi jumlah nilai unik ini mengonfirmasi adanya **kombinasi yang seimbang antara variabel kategorikal, diskrit, dan kontinu**, sehingga dataset ini **sangat cocok untuk exploratory data analysis dan pemodelan machine learning**.

# %%
# Replace Inf values with NaN if any
df = df.replace([np.inf, -np.inf], np.nan)

# %%
# lets try to check the missing values of each column in a dataset
missing = (df.isnull().mean()) > 0
missing_values_count = df.isnull().sum()[missing]
missing_values_percentage = ((df.isnull().sum() / len(df)) * 100)[missing]

missing_values_info = pd.DataFrame({
    'Missing Count': missing_values_count,
    'Missing Percentage': missing_values_percentage
})
missing_values_info = missing_values_info.sort_values(by='Missing Count', ascending=False)
missing_values_info
# Out:
#                              Missing Count  Missing Percentage
# DaySinceLastOrder                      307            5.452931
# OrderAmountHikeFromlastYear            265            4.706927
# Tenure                                 264            4.689165
# OrderCount                             258            4.582593
# CouponUsed                             256            4.547069
# HourSpendOnApp                         255            4.529307
# WarehouseToHome                        251            4.458259

# %%
# lets try to check the total missing values in the dataset
print("Total Missing Values : ", df.isnull().sum().sum())
# Out:
# Total Missing Values :  1856

# %% [markdown]
# * Analisis missing value menunjukkan bahwa seluruh data yang hilang **terkonsentrasi pada fitur numerik**, dengan persentase berkisar antara **~4,45% hingga ~5,45%**, yang tergolong **rendah dan masih mudah ditangani**.
#
# * `DaySinceLastOrder` memiliki persentase missing tertinggi (**5,45%**), diikuti oleh `OrderAmountHikeFromLastYear` (**4,71%**) dan `Tenure` (**4,69%**).
#
# * Fitur numerik lainnya seperti
#   `OrderCount, CouponUsed, HourSpendOnApp, dan WarehouseToHome`
#   juga memiliki proporsi missing value yang relatif serupa, yang menunjukkan **tidak adanya kehilangan data ekstrem pada satu fitur tertentu**.
#
# * Karena persentase missing value relatif rendah, **mean imputation** merupakan strategi yang tepat untuk kolom numerik, karena dapat **mempertahankan distribusi data secara keseluruhan tanpa menimbulkan bias yang signifikan**.
#
# * Fitur kategorikal (`PreferredLoginDevice dan PreferredPaymentMode`) diimputasi menggunakan **nilai yang paling sering muncul (mode)**, yang merupakan pendekatan standar dan efektif untuk variabel nominal.
#
# * Strategi imputasi ini memastikan **tidak ada baris data yang dibuang**, menjaga **ukuran dataset tetap utuh**, serta **mempersiapkan data untuk proses pemodelan dan analisis lanjutan secara lancar**.

# %%
# Identify numerical and categorical columns
numerical_cols = [
    'Tenure', 'WarehouseToHome', 'HourSpendOnApp',
    'OrderAmountHikeFromlastYear', 'CouponUsed',
    'OrderCount', 'DaySinceLastOrder'
]

categorical_cols = [
    'PreferredLoginDevice', 'PreferredPaymentMode'
]

# Handle missing values

# Fill numerical columns with mean
df[numerical_cols] = df[numerical_cols].fillna(df[numerical_cols].mean())

# Fill categorical columns with mode (most frequent value)
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# %%
# Verify missing values after imputation
print("Missing values after handling:")
print(df.isnull().sum())
# Out:
# Missing values after handling:
# CustomerID                     0
# Churn                          0
# Tenure                         0
# PreferredLoginDevice           0
# CityTier                       0
# WarehouseToHome                0
# PreferredPaymentMode           0
# Gender                         0
# HourSpendOnApp                 0
# NumberOfDeviceRegistered       0
# PreferedOrderCat               0
# SatisfactionScore              0
# MaritalStatus                  0
# NumberOfAddress                0
# Complain                       0
# OrderAmountHikeFromlastYear    0
# CouponUsed                     0
# OrderCount                     0
# DaySinceLastOrder              0
# CashbackAmount                 0
# dtype: int64

# %%
df.head()
# Out:
#    CustomerID  Churn     Tenure PreferredLoginDevice  CityTier  \
# 0       50001      1   4.000000         Mobile Phone         3
# 1       50002      1  10.189899         Mobile Phone         1
# 2       50003      1  10.189899         Mobile Phone         1
# 3       50004      1   0.000000         Mobile Phone         3
# 4       50005      1   0.000000         Mobile Phone         1
#
#    WarehouseToHome PreferredPaymentMode  Gender  HourSpendOnApp  \
# 0              6.0           Debit Card  Female        3.000000
# 1              8.0                  UPI    Male        3.000000
# 2             30.0           Debit Card    Male        2.000000
# 3             15.0           Debit Card    Male        2.000000
# 4             12.0          Credit Card    Male        2.931535
#
#    NumberOfDeviceRegistered    PreferedOrderCat  SatisfactionScore  \
# 0                         3  Laptop & Accessory                  2
# ...

# %%
def get_overall_info_about_dataset(df):
    '''
    lets try to check the percentage of missing values,unique values,percentage of one catagory values
    and type against each column.
    '''
    stats = []
    for col in df.columns:
        stats.append((col, df[col].nunique(), df[col].isnull().sum() * 100 / df.shape[0], df[col].value_counts(normalize=True, dropna=False).values[0] * 100, df[col].dtype))
    stats_df = pd.DataFrame(stats, columns=['Feature', 'Unique_values', '% MissingValues', '% highOneCategoricalValues', 'type'])
    df_ = stats_df.sort_values('% MissingValues', ascending=False)
    print(tabulate(df_, headers = 'keys', tablefmt = 'psql'))

# %%
get_overall_info_about_dataset(df)
# Out:
# +----+-----------------------------+-----------------+-------------------+------------------------------+---------+
# |    | Feature                     |   Unique_values |   % MissingValues |   % highOneCategoricalValues | type    |
# |----+-----------------------------+-----------------+-------------------+------------------------------+---------|
# |  0 | CustomerID                  |            5630 |                 0 |                     0.017762 | int64   |
# |  1 | Churn                       |               2 |                 0 |                    83.1616   | int64   |
# |  2 | Tenure                      |              37 |                 0 |                    12.2558   | float64 |
# |  3 | PreferredLoginDevice        |               2 |                 0 |                    70.9769   | object  |
# |  4 | CityTier                    |               3 |                 0 |                    65.1155   | int64   |
# ...

# %% [markdown]
# * Analisis per fitur mengonfirmasi bahwa **seluruh missing values telah berhasil ditangani**, dengan persentase missing value kini **0% pada setiap fitur**.
#
# * `CustomerID` memiliki nilai unik untuk setiap baris data (**5.630 nilai unik**), yang menunjukkan bahwa fitur ini berfungsi sebagai **identifier**, bukan fitur prediktif, sehingga **perlu dikecualikan dari proses training model**.
#
# * Variabel target `Churn` memiliki **2 kelas unik** dengan dominasi yang tinggi pada salah satu kelas, yang mengindikasikan adanya **class imbalance** dan mungkin memerlukan teknik seperti **resampling** atau **class weighting**.
#
# * Fitur kategorikal seperti
#   `PreferredLoginDevice, Gender, Complain, CityTier, dan MaritalStatus`
#   menunjukkan dominasi kategori yang tinggi, yang mengindikasikan **distribusi data yang skewed** dan berpotensi memengaruhi proses pembelajaran model.
#
# * Fitur numerik seperti
#   `Tenure, WarehouseToHome, OrderAmountHikeFromLastYear, OrderCount, dan DaySinceLastOrder`
#   memiliki variasi yang moderat dan **sesuai untuk dilakukan scaling atau normalization**.
#
# * `CashbackAmount` menonjol dengan **2.586 nilai unik**, menjadikannya fitur yang **sangat kontinu** dengan dominasi yang minimal, serta **berpotensi memiliki daya prediksi yang kuat**.
#
# * Secara keseluruhan, dataset kini **bersih, konsisten, dan terstruktur dengan baik**, sehingga **siap untuk proses feature encoding, penanganan class imbalance, dan pengembangan model machine learning**.

# %% [markdown]
# * Kolom `CustomerID` perlu dihapus dari dataset sebelum proses pemodelan karena:
#   * Kolom ini hanya berfungsi sebagai **unique identifier** untuk setiap pelanggan dan **tidak mengandung informasi prediktif** yang berkaitan dengan customer churn.

# %%
# Drop the CustomerID column as it is irrelevant for prediction
df = df.drop(columns=['CustomerID'])

# Verify removal
print(df.columns)
# Out:
# Index(['Churn', 'Tenure', 'PreferredLoginDevice', 'CityTier',
#        'WarehouseToHome', 'PreferredPaymentMode', 'Gender', 'HourSpendOnApp',
#        'NumberOfDeviceRegistered', 'PreferedOrderCat', 'SatisfactionScore',
#        'MaritalStatus', 'NumberOfAddress', 'Complain',
#        'OrderAmountHikeFromlastYear', 'CouponUsed', 'OrderCount',
#        'DaySinceLastOrder', 'CashbackAmount'],
#       dtype='object')

# %%
def analyze_categorical(df, categorical_cols, show_percentage=True):
    plt.figure(figsize=(18, 12))
    plt.suptitle('Univariate Analysis of Categorical Columns', fontsize=18, y=1.02)

    for i, col in enumerate(categorical_cols):
        plt.subplot(3, 2, i + 1)
        ax = sns.countplot(x=col, data=df, palette='pastel')

        # Add counts and percentages on bars
        total = len(df)
        for p in ax.patches:
            count = int(p.get_height())
            if show_percentage:
                percentage = count / total * 100
                label = f'{count}\n({percentage:.1f}%)'
            else:
                label = f'{count}'
            ax.annotate(label,
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='bottom', fontsize=11, color='black')

        plt.xlabel(col, fontsize=12)
        plt.ylabel('Count', fontsize=12)
        plt.xticks(rotation=45)

    plt.tight_layout()
    plt.show()

# %%
cat_cols = df.select_dtypes(include=['object']).columns.tolist()
analyze_categorical(df, cat_cols)

# %%
def categorical_summary(df, categorical_cols):
    summary_list = []

    for col in categorical_cols:
        counts = df[col].value_counts()
        percentages = df[col].value_counts(normalize=True) * 100

        for cat in counts.index:
            summary_list.append({
                'Feature': col,
                'Category': cat,
                'Count': counts[cat],
                'Percentage': round(percentages[cat], 2)
            })

    summary_df = pd.DataFrame(summary_list)
    return summary_df

# %%
category_table = categorical_summary(df, cat_cols)
print(tabulate(category_table, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+----------------------+--------------------+---------+--------------+
# |    | Feature              | Category           |   Count |   Percentage |
# |----+----------------------+--------------------+---------+--------------|
# |  0 | PreferredLoginDevice | Mobile Phone       |    3996 |        70.98 |
# |  1 | PreferredLoginDevice | Computer           |    1634 |        29.02 |
# |  2 | PreferredPaymentMode | Debit Card         |    2314 |        41.1  |
# |  3 | PreferredPaymentMode | Credit Card        |    1774 |        31.51 |
# |  4 | PreferredPaymentMode | E wallet           |     614 |        10.91 |
# |  5 | PreferredPaymentMode | Cash on Delivery   |     514 |         9.13 |
# |  6 | PreferredPaymentMode | UPI                |     414 |         7.35 |
# |  7 | Gender               | Male               |    3384 |        60.11 |
# |  8 | Gender               | Female             |    2246 |        39.89 |
# ...

# %% [markdown]
# **PreferredLoginDevice:**
#
# * Mayoritas pelanggan (**70.98%**) menggunakan **Mobile Phone** untuk mengakses platform, sementara **29.02%** menggunakan **Computer**.
#
# * Hal ini menunjukkan bahwa platform ini **lebih banyak diakses melalui perangkat mobile**, yang dapat memengaruhi strategi optimasi aplikasi dan pemasaran.
#
# **PreferredPaymentMode:**
#
# * Sebagian besar pelanggan lebih memilih **Debit Card (41.10%)** dan **Credit Card (31.51%)** sebagai metode pembayaran.
#
# * Metode pembayaran lain seperti **E wallet (10.91%)**, **Cash on Delivery (9.13%)**, dan **UPI (7.35%)** memiliki persentase penggunaan yang lebih kecil.
#
# * Hal ini menunjukkan bahwa **pembayaran digital mendominasi**, namun **COD dan e-wallet** masih relevan bagi sebagian pengguna.
#
# **Gender:**
#
# * Basis pelanggan didominasi oleh **Male (60.11%)**, sementara pelanggan **Female** mencakup **39.89%**.
#
# * Informasi ini dapat dimanfaatkan untuk **kampanye yang lebih tersegmentasi berdasarkan gender** atau rekomendasi yang lebih personal.
#
# **PreferedOrderCat:**
#
# * Kategori yang paling sering dipesan adalah **Mobile Phone (36.94%)** dan **Laptop & Accessory (36.41%)**, diikuti oleh **Fashion (14.67%)**, **Grocery (7.28%)**, dan **Others (4.69%)**.
#
# * Hal ini menunjukkan bahwa **produk elektronik mendominasi transaksi**, sementara kategori lain memiliki tingkat keterlibatan yang lebih rendah.
#
# **MaritalStatus:**
#
# * Lebih dari setengah pelanggan berstatus **Married (53.04%)**, diikuti oleh **Single (31.90%)** dan **Divorced (15.06%)**.

# %%
def target_distribution(df_final, col):
    plt.figure(figsize=(17, 7))

    plt.subplot(1, 2, 1)

    ax = df_final[col].map({0:'Not Churned', 1:'Churned'}).value_counts().plot(kind = 'bar', color = ['green', 'red'])

    plt.xlabel('Target Category', fontsize=16)
    plt.ylabel('Frequency of Target', fontsize=16)
    plt.xticks(size = 12)
    plt.yticks(size = 12)
    plt.title('Frequency Distribution of Customers\n who Left', fontsize=18)
    for p in ax.patches:
        ax.annotate(str(p.get_height()), (p.get_x() * 1.05, p.get_height() * 1.01), size=15)


    plt.subplot(1,2,2)

    df_final[col].map({0:'Not Churned', 1:'Churned'}).value_counts().plot.pie(explode=[0.02,0.02],autopct='%1.2f%%',shadow=True, colors = ['green', 'red'],
                                        textprops={'fontsize':15, 'color':'white'})
    plt.ylabel('target', fontsize=16)
    plt.title('Proportional Distribution of Customers\n who Left', fontsize=18)
    plt.legend()
    plt.show()

# %%
target_distribution(df, 'Churn')

# %% [markdown]
# **Distribusi Churn:**
#
# * Dari total **5.630 pelanggan**, sebanyak **4.682 pelanggan (83.16%)** **tidak mengalami churn**, sedangkan **948 pelanggan (16.84%)** **mengalami churn**.
#
# * Hal ini menunjukkan adanya **ketidakseimbangan kelas (class imbalance)** yang cukup tinggi, di mana mayoritas pelanggan masih aktif.
#
# **Implikasi:**
#
# * Ketidakseimbangan ini mengindikasikan bahwa proses training model memerlukan **penanganan khusus**, seperti:
#   * **Class weighting** pada algoritma
#   * **Oversampling** pada kelas minoritas (misalnya menggunakan **SMOTE**)
#   * **Undersampling** pada kelas mayoritas
#
# * Penanganan yang tepat sangat penting untuk **mencegah model menjadi bias terhadap kelas mayoritas** dan memastikan performa prediksi churn yang lebih akurat.

# %%
def analyze_categorical_with_target(df, categorical_cols, target='Churn', show_percentage=True):
    plt.figure(figsize=(18, 14))
    plt.suptitle(f'Categorical Features vs {target}', fontsize=18, y=1.02)

    summary_list = []

    for i, col in enumerate(categorical_cols):
        plt.subplot(3, 3, i + 1)
        ax = sns.countplot(x=col, hue=target, data=df, palette='pastel')

        total = len(df)
        for p in ax.patches:
            height = p.get_height()
            if show_percentage:
                perc = height / total * 100
                label = f'{int(height)}\n({perc:.1f}%)'
            else:
                label = f'{int(height)}'
            ax.annotate(label,
                        (p.get_x() + p.get_width() / 2., height),
                        ha='center', va='bottom', fontsize=11, color='black')

        plt.xlabel(col, fontsize=12)
        plt.ylabel('Count', fontsize=12)
        plt.xticks(rotation=45)
        plt.legend(title=target)
    plt.tight_layout()
    plt.show()

# %%
df_copy = df.copy()
df_copy['Churn'] = df_copy["Churn"].map({0:'Not Churned', 1:'Churned'})
df_copy['Complain'] = df_copy['Complain'].map({1: 'Complain', 0: 'No Complain'})

df_copy['CityTier'] = df_copy['CityTier'].map({1: 'Tier 1 - Metropolitan',
                                     2: 'Tier 2 - Moderate Urban',
                                     3: 'Tier 3 - Rural/Small Town'})

# %%
analyze_categorical_with_target(df_copy, cat_cols+['Complain', 'CityTier'], target='Churn')

# %%
def churn_categorical_summary(df, categorical_cols, target='Churn'):
    summary_list = []

    total_rows = len(df)

    for col in categorical_cols:
        grouped = df.groupby([col, target]).size().reset_index(name='Count')
        grouped['Percentage'] = round(grouped['Count'] / total_rows * 100, 2)
        grouped = grouped.rename(columns={col: 'Category', target: 'Churn Status'})
        grouped['Feature'] = col
        summary_list.append(grouped)

    summary_df = pd.concat(summary_list, ignore_index=True)
    summary_df = summary_df[['Feature', 'Category', 'Churn Status', 'Count', 'Percentage']]

    return summary_df


churn_table = churn_categorical_summary(df_copy, cat_cols+['Complain', 'CityTier'])
print(tabulate(churn_table, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+----------------------+---------------------------+----------------+---------+--------------+
# |    | Feature              | Category                  | Churn Status   |   Count |   Percentage |
# |----+----------------------+---------------------------+----------------+---------+--------------|
# |  0 | PreferredLoginDevice | Computer                  | Churned        |     324 |         5.75 |
# |  1 | PreferredLoginDevice | Computer                  | Not Churned    |    1310 |        23.27 |
# |  2 | PreferredLoginDevice | Mobile Phone              | Churned        |     624 |        11.08 |
# |  3 | PreferredLoginDevice | Mobile Phone              | Not Churned    |    3372 |        59.89 |
# |  4 | PreferredPaymentMode | Cash on Delivery          | Churned        |     128 |         2.27 |
# |  5 | PreferredPaymentMode | Cash on Delivery          | Not Churned    |     386 |         6.86 |
# ...

# %% [markdown]
# | Feature              | Category                  | Churned % | Not Churned % | Insight                                                                 |
# | -------------------- | ------------------------- | --------- | ------------- | ----------------------------------------------------------------------- |
# | PreferredLoginDevice | Mobile Phone              | 11.08     | 59.89         | Tingkat churn lebih tinggi pada pengguna mobile.                        |
# | PreferredLoginDevice | Computer                  | 5.75      | 23.27         | Tingkat churn lebih rendah dibandingkan pengguna mobile.               |
# | PreferredPaymentMode | Debit Card                | 6.32      | 34.78         | Churn sedikit lebih tinggi pada pengguna debit card.                   |
# | PreferredPaymentMode | Credit Card               | 4.48      | 27.03         | Tingkat churn sedang.                                                   |
# | PreferredPaymentMode | E wallet                  | 2.49      | 8.42          | Tingkat churn rendah.                                                   |
# | PreferredPaymentMode | UPI                       | 1.28      | 6.07          | Tingkat churn rendah.                                                   |
# | PreferredPaymentMode | Cash on Delivery          | 2.27      | 6.86          | Tingkat churn rendah.                                                   |
# | Gender               | Male                      | 10.66     | 49.45         | Pelanggan laki-laki menunjukkan proporsi churn yang lebih tinggi.      |
# | Gender               | Female                    | 6.18      | 33.71         | Tingkat churn lebih rendah dibandingkan pelanggan laki-laki.           |
# | PreferedOrderCat     | Laptop & Accessory        | 3.73      | 32.68         | Tingkat churn sedang.                                                   |
# | PreferedOrderCat     | Mobile Phone              | 10.12     | 26.82         | Tingkat churn tertinggi di antara kategori pesanan.                    |
# | PreferedOrderCat     | Fashion                   | 2.27      | 12.40         | Tingkat churn rendah.                                                   |
# | PreferedOrderCat     | Grocery                   | 0.36      | 6.93          | Tingkat churn sangat minimal.                                          |
# | PreferedOrderCat     | Others                    | 0.36      | 4.33          | Tingkat churn sangat minimal.                                          |
# | MaritalStatus        | Married                   | 6.11      | 46.93         | Tingkat churn lebih rendah dibandingkan pelanggan single.              |
# | MaritalStatus        | Single                    | 8.53      | 23.37         | Tingkat churn tertinggi di antara status pernikahan.                   |
# | MaritalStatus        | Divorced                  | 2.20      | 12.86         | Tingkat churn terendah di antara status pernikahan.                    |
# | Complain             | Complain                  | 9.02      | 19.47         | Tingkat churn lebih tinggi pada pengguna yang melakukan komplain.      |
# | Complain             | No Complain               | 7.82      | 63.69         | Tingkat churn lebih rendah pada pengguna tanpa komplain.               |
# | CityTier             | Tier 1 - Metropolitan     | 9.45      | 55.67         | Tingkat churn tinggi di wilayah metropolitan.                          |
# | CityTier             | Tier 2 - Moderate Urban   | 0.85      | 3.45          | Tingkat churn sangat rendah di wilayah urban menengah.                 |
# | CityTier             | Tier 3 - Rural/Small Town | 6.54      | 24.05         | Tingkat churn sedang di wilayah pedesaan/kota kecil.                  |

# %%
df.head()
# Out:
#    Churn     Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1   4.000000         Mobile Phone         3              6.0
# 1      1  10.189899         Mobile Phone         1              8.0
# 2      1  10.189899         Mobile Phone         1             30.0
# 3      1   0.000000         Mobile Phone         3             15.0
# 4      1   0.000000         Mobile Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female        3.000000                         3
# 1                  UPI    Male        3.000000                         4
# 2           Debit Card    Male        2.000000                         4
# 3           Debit Card    Male        2.000000                         4
# 4          Credit Card    Male        2.931535                         3
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %%
def violin_analysis_with_mean(df, target='Churn', continuous_features=None):
    if continuous_features is None:
        continuous_features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
        if target in continuous_features:
            continuous_features.remove(target)

    # --- Violin Plots ---
    plt.figure(figsize=(18, 30))
    plt.suptitle('Numerical/Continuous Features by ' + target, fontsize=22, y=1.02)

    for j, feature in enumerate(continuous_features):
        plt.subplot((len(continuous_features)+1)//2, 2, j+1)
        sns.violinplot(x=target, y=feature, data=df, palette=['red', 'lime'])
        plt.title(feature, fontsize=14)
        mean_val = df[feature].mean()
        plt.axhline(mean_val, linestyle='dashed', color='blue',
                    label=f"Overall Mean = {round(mean_val, 2)}")
        plt.legend(loc='best')
        plt.tight_layout()

    plt.show()

    # --- Mean Table by Target ---
    mean_by_target = df[continuous_features + [target]].groupby(target).mean().T
    mean_by_target.reset_index(inplace=True)
    mean_by_target.columns = ['Feature'] + [f"Mean_{str(col)}" for col in mean_by_target.columns[1:]]

    return mean_by_target

# %%
continuous_features = [
    'Tenure', 'WarehouseToHome', 'HourSpendOnApp', 'NumberOfDeviceRegistered',
    'SatisfactionScore', 'NumberOfAddress', 'OrderAmountHikeFromlastYear',
    'CouponUsed', 'OrderCount', 'DaySinceLastOrder', 'CashbackAmount'
]

mean_table = violin_analysis_with_mean(df_copy, target='Churn', continuous_features=continuous_features)
display(mean_table)
# Out:
#                         Feature  Mean_Churned  Mean_Not Churned
# 0                        Tenure      3.961373         11.451036
# 1               WarehouseToHome     17.001847         15.364131
# 2                HourSpendOnApp      2.959946          2.925782
# 3      NumberOfDeviceRegistered      3.934599          3.639257
# 4             SatisfactionScore      3.390295          3.001282
# 5               NumberOfAddress      4.466245          4.162965
# 6   OrderAmountHikeFromlastYear     15.628598         15.723983
# 7                    CouponUsed      1.717308          1.757850
# 8                    OrderCount      2.827156          3.044622
# 9             DaySinceLastOrder      3.310494          4.793145
# 10               CashbackAmount    160.370928        180.635203

# %% [markdown]
# | Feature                     | Mean (Churned) | Mean (Not Churned) | Insight                                                                                                                                 |
# | --------------------------- | -------------- | ------------------ | --------------------------------------------------------------------------------------------------------------------------------------- |
# | Tenure                      | 3.96           | 11.45              | Pelanggan yang churn memiliki masa berlangganan yang lebih singkat, menunjukkan bahwa loyalitas cenderung meningkat seiring bertambahnya tenure. |
# | WarehouseToHome             | 17.00          | 15.36              | Pelanggan yang churn cenderung tinggal sedikit lebih jauh dari gudang, yang dapat memengaruhi pengalaman pengiriman.                    |
# | HourSpendOnApp              | 2.96           | 2.93               | Hampir tidak ada perbedaan; penggunaan aplikasi relatif sama antara pelanggan churn dan yang bertahan.                                 |
# | NumberOfDeviceRegistered    | 3.93           | 3.64               | Pelanggan yang churn memiliki sedikit lebih banyak perangkat terdaftar, namun perbedaannya relatif kecil.                               |
# | SatisfactionScore           | 3.39           | 3.00               | Pelanggan yang churn melaporkan skor kepuasan sedikit lebih tinggi, yang mengindikasikan adanya faktor lain di luar kepuasan yang memicu churn. |
# | NumberOfAddress             | 4.47           | 4.16               | Pelanggan yang churn memiliki lebih banyak alamat, kemungkinan karena eksperimen akun atau akun yang sudah tidak aktif.                  |
# | OrderAmountHikeFromlastYear | 15.63          | 15.72              | Nilainya sangat mirip, menunjukkan tidak ada perbedaan signifikan dalam pertumbuhan nilai pesanan antara kedua kelompok.                 |
# | CouponUsed                  | 1.72           | 1.76               | Perbedaannya sangat kecil; penggunaan kupon tidak memiliki pengaruh kuat terhadap churn.                                                |
# | OrderCount                  | 2.83           | 3.04               | Pelanggan yang churn melakukan jumlah pesanan yang sedikit lebih rendah dibandingkan pelanggan yang bertahan.                           |
# | DaySinceLastOrder           | 3.31           | 4.79               | Pelanggan yang bertahan memiliki jarak waktu lebih lama sejak pesanan terakhir; pelanggan churn lebih baru, yang dapat mencerminkan keterlibatan yang tidak teratur. |
# | CashbackAmount              | 160.37         | 180.64             | Pelanggan yang bertahan menerima cashback rata-rata lebih tinggi, yang dapat mendorong keterlibatan dan retensi pelanggan.              |

# %%
# check the outliers by plot the box plot
plt.figure(figsize=(25,15))
sns.boxplot(data=df[continuous_features])
plt.xticks(rotation=90)
plt.show()

# %%
# Detect outliers using IQR
outliers_dict = {}

for feature in continuous_features:
    Q1 = df[feature].quantile(0.25)
    Q3 = df[feature].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[feature] < lower_bound) | (df[feature] > upper_bound)]
    outliers_dict[feature] = outliers.shape[0]

# Convert to a dataframe for better visualization
outliers_df = pd.DataFrame(list(outliers_dict.items()), columns=['Feature', 'Outlier_Count'])
outliers_df['Outlier_Percentage'] = (outliers_df['Outlier_Count'] / df.shape[0] * 100).round(2)

display(outliers_df)
# Out:
#                         Feature  Outlier_Count  Outlier_Percentage
# 0                        Tenure              4                0.07
# 1               WarehouseToHome              2                0.04
# 2                HourSpendOnApp              6                0.11
# 3      NumberOfDeviceRegistered            397                7.05
# 4             SatisfactionScore              0                0.00
# 5               NumberOfAddress              4                0.07
# 6   OrderAmountHikeFromlastYear             33                0.59
# 7                    CouponUsed            629               11.17
# 8                    OrderCount            703               12.49
# 9             DaySinceLastOrder             62                1.10
# 10               CashbackAmount            438                7.78

# %% [markdown]
# | Feature                     | Outlier Count | Outlier Percentage | Insight                                                                                           |
# | --------------------------- | ------------- | ------------------ | ------------------------------------------------------------------------------------------------- |
# | Tenure                      | 4             | 0.07%              | Jumlah outlier sangat sedikit — sebagian besar pelanggan memiliki nilai tenure dalam rentang normal. |
# | WarehouseToHome             | 2             | 0.04%              | Outlier sangat minim — jarak pelanggan ke gudang relatif konsisten.                               |
# | HourSpendOnApp              | 6             | 0.11%              | Outlier dapat diabaikan — penggunaan aplikasi relatif seragam.                                    |
# | NumberOfDeviceRegistered    | 397           | 7.05%              | Outlier cukup signifikan — beberapa pengguna memiliki jumlah perangkat terdaftar yang tidak biasa. |
# | SatisfactionScore           | 0             | 0.00%              | Tidak ada outlier — skor kepuasan berada dalam rentang yang wajar.                                |
# | NumberOfAddress             | 4             | 0.07%              | Sangat sedikit outlier — sebagian besar pengguna memiliki jumlah alamat yang umum.               |
# | OrderAmountHikeFromlastYear | 33            | 0.59%              | Outlier ringan — hanya sebagian kecil pengguna dengan pertumbuhan nilai pesanan yang sangat tinggi. |
# | CouponUsed                  | 629           | 11.17%             | Jumlah outlier tinggi — beberapa pengguna menggunakan kupon dalam jumlah yang sangat besar.      |
# | OrderCount                  | 703           | 12.49%             | Persentase outlier tinggi — sebagian pengguna melakukan jumlah pesanan yang jauh lebih tinggi dari rata-rata. |
# | DaySinceLastOrder           | 62            | 1.10%              | Sedikit outlier — beberapa pengguna tidak melakukan pemesanan dalam jangka waktu yang jauh lebih lama dari rata-rata. |
# | CashbackAmount              | 438           | 7.78%              | Outlier cukup terlihat — beberapa pengguna menerima cashback yang jauh lebih besar dari umumnya. |

# %%
# fix the outliers
def replace_outliers_with_mean(df, columns):
    for column in columns:
        # Calculate Q1 and Q3
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)

        # Calculate IQR
        IQR = Q3 - Q1

        # Define lower and upper bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Replace outliers with the mean
        mean_value = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)][column].mean()
        df.loc[(df[column] < lower_bound) | (df[column] > upper_bound), column] = mean_value

    return df

# %%
data_new = replace_outliers_with_mean(df, continuous_features)

# %%
def plot_graph(df, features_list):
  for col in features_list:
    fig, ax =plt.subplots(1,2, figsize=(15,3))
    sns.distplot(df[col], ax=ax[0]).set(title="Distribution")
    sns.boxplot(x= col,data=df, ax=ax[1]).set(title="Outlier")
    plt.suptitle(f'{col.title()}',weight='bold')
    plt.tight_layout()

# %%
# verify the outliers
plot_graph(data_new, continuous_features)

# %%
df.head()
# Out:
#    Churn     Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1   4.000000         Mobile Phone         3              6.0
# 1      1  10.189899         Mobile Phone         1              8.0
# 2      1  10.189899         Mobile Phone         1             30.0
# 3      1   0.000000         Mobile Phone         3             15.0
# 4      1   0.000000         Mobile Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female        3.000000                       3.0
# 1                  UPI    Male        3.000000                       4.0
# 2           Debit Card    Male        2.000000                       4.0
# 3           Debit Card    Male        2.000000                       4.0
# 4          Credit Card    Male        2.931535                       3.0
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %% [markdown]
# #### **Label Encoding**
# - Label Encoding adalah proses **mengubah label kategorikal menjadi bentuk numerik** agar dapat dibaca dan diproses oleh mesin.
# - Dengan representasi numerik ini, **algoritma machine learning dapat mempelajari dan mengolah label dengan lebih efektif**. Label Encoding merupakan **tahap preprocessing yang penting** untuk dataset terstruktur dalam **supervised learning**.

# %%
cat = df.select_dtypes(include=['object']).columns.tolist()

# %%
unique_values = []
for i in cat:
    unique_values.append((i, df[i].unique()))

# %%
df_unique_values = pd.DataFrame(unique_values, columns=['Features', 'Unique_Values'])
df_unique_values
# Out:
#                Features                                      Unique_Values
# 0  PreferredLoginDevice                           [Mobile Phone, Computer]
# 1  PreferredPaymentMode  [Debit Card, UPI, Credit Card, Cash on Deliver...
# 2                Gender                                     [Female, Male]
# 3      PreferedOrderCat  [Laptop & Accessory, Mobile Phone, Others, Fas...
# 4         MaritalStatus                        [Single, Divorced, Married]

# %%
from sklearn.preprocessing import LabelEncoder

def encode_categorical(df, cat_cols=None):

    df_encoded = df.copy()
    mappings = {}

    # Select categorical columns if not provided
    if cat_cols is None:
        cat_cols = df_encoded.select_dtypes(include=['object']).columns.tolist()

    # Encode each categorical column
    for col in cat_cols:
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col])
        mappings[col] = dict(zip(le.classes_, le.transform(le.classes_)))

    return df_encoded, mappings

# %%
import os

def save_dataframe_to_csv(df, directory, filename, index=False):
    # Create directory if not exists
    os.makedirs(directory, exist_ok=True)

    # Full file path
    file_path = os.path.join(directory, filename)

    # Save DataFrame
    df.to_csv(file_path, index=index)

    print(f"CSV file saved successfully at:\n{file_path}")

# %%
save_dataframe_to_csv(
    df=df,
    directory="/content/drive/MyDrive/Ecommerce_Customer",
    filename="ecommerce_cleaned_data.csv"
)
# Out:
# CSV file saved successfully at:
# /content/drive/MyDrive/Ecommerce_Customer/ecommerce_cleaned_data.csv

# %%
# Encode all categorical columns
df_encoded, cat_mappings = encode_categorical(df)

# Display encoded dataframe
df_encoded.head()
# Out:
#    Churn     Tenure  PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1   4.000000                     1         3              6.0
# 1      1  10.189899                     1         1              8.0
# 2      1  10.189899                     1         1             30.0
# 3      1   0.000000                     1         3             15.0
# 4      1   0.000000                     1         1             12.0
#
#    PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0                     2       0        3.000000                       3.0
# 1                     4       1        3.000000                       4.0
# 2                     2       1        2.000000                       4.0
# 3                     2       1        2.000000                       4.0
# 4                     1       1        2.931535                       3.0
#
#    PreferedOrderCat  SatisfactionScore  MaritalStatus  NumberOfAddress  \
# ...

# %%
# Display mapping for reference
for col, mapping in cat_mappings.items():
    print(f"{col}: {mapping}")
# Out:
# PreferredLoginDevice: {'Computer': np.int64(0), 'Mobile Phone': np.int64(1)}
# PreferredPaymentMode: {'Cash on Delivery': np.int64(0), 'Credit Card': np.int64(1), 'Debit Card': np.int64(2), 'E wallet': np.int64(3), 'UPI': np.int64(4)}
# Gender: {'Female': np.int64(0), 'Male': np.int64(1)}
# PreferedOrderCat: {'Fashion': np.int64(0), 'Grocery': np.int64(1), 'Laptop & Accessory': np.int64(2), 'Mobile Phone': np.int64(3), 'Others': np.int64(4)}
# MaritalStatus: {'Divorced': np.int64(0), 'Married': np.int64(1), 'Single': np.int64(2)}

# %%
df.head()
# Out:
#    Churn     Tenure PreferredLoginDevice  CityTier  WarehouseToHome  \
# 0      1   4.000000         Mobile Phone         3              6.0
# 1      1  10.189899         Mobile Phone         1              8.0
# 2      1  10.189899         Mobile Phone         1             30.0
# 3      1   0.000000         Mobile Phone         3             15.0
# 4      1   0.000000         Mobile Phone         1             12.0
#
#   PreferredPaymentMode  Gender  HourSpendOnApp  NumberOfDeviceRegistered  \
# 0           Debit Card  Female        3.000000                       3.0
# 1                  UPI    Male        3.000000                       4.0
# 2           Debit Card    Male        2.000000                       4.0
# 3           Debit Card    Male        2.000000                       4.0
# 4          Credit Card    Male        2.931535                       3.0
#
#      PreferedOrderCat  SatisfactionScore MaritalStatus  NumberOfAddress  \
# ...

# %%
df = df_encoded.copy()

# %%
# lets try to check the correlation of each feature with target
sns.set(rc = {'figure.figsize':(20,10)})
sns.heatmap(df.corr(), annot = True, fmt='.2g',cmap= 'coolwarm')
plt.show()

PCC = df.corr()['Churn'].values
dic = {
    'feature' : df.corr()['Churn'].index,
    'CorrelationWithTarget' : PCC
}
pcc_df = pd.DataFrame(dic).sort_values(by = 'CorrelationWithTarget',ascending=False)[1:].reset_index()
pcc_df = pcc_df.drop('index', axis=1)
print(tabulate(pcc_df, headers = 'keys', tablefmt = 'psql'))
# Out:
# +----+-----------------------------+-------------------------+
# |    | feature                     |   CorrelationWithTarget |
# |----+-----------------------------+-------------------------|
# |  0 | Complain                    |              0.250188   |
# |  1 | MaritalStatus               |              0.140316   |
# |  2 | SatisfactionScore           |              0.105481   |
# |  3 | PreferedOrderCat            |              0.104569   |
# |  4 | CityTier                    |              0.0847032  |
# |  5 | WarehouseToHome             |              0.0781163  |
# |  6 | NumberOfDeviceRegistered    |              0.0739691  |
# |  7 | NumberOfAddress             |              0.0409114  |
# |  8 | Gender                      |              0.0292636  |
# |  9 | HourSpendOnApp              |              0.0179561  |
# | 10 | PreferredPaymentMode        |              0.00234485 |
# | 11 | OrderAmountHikeFromlastYear |             -0.0052054  |
# ...

# %% [markdown]
# | Feature                     | Correlation with Churn | Insight                                                                                                                                   |
# | --------------------------- | ---------------------- | ----------------------------------------------------------------------------------------------------------------------------------------- |
# | Complain                    | 0.25                   | **Korelasi positif tertinggi** — pelanggan yang pernah melakukan komplain memiliki kemungkinan churn yang lebih tinggi.                  |
# | MaritalStatus               | 0.14                   | Korelasi positif — status pernikahan memengaruhi churn; pelanggan single cenderung lebih mudah churn.                                     |
# | SatisfactionScore           | 0.11                   | Korelasi positif lemah — menariknya, tingkat kepuasan yang lebih tinggi sedikit berkaitan dengan churn, menandakan adanya faktor lain.   |
# | PreferedOrderCat            | 0.10                   | Kategori pesanan tertentu sedikit meningkatkan kemungkinan churn.                                                                         |
# | CityTier                    | 0.08                   | Pelanggan dari city tier tertentu memiliki kecenderungan churn yang sedikit lebih tinggi.                                                |
# | WarehouseToHome             | 0.08                   | Jarak yang lebih jauh dari gudang sedikit meningkatkan kemungkinan churn.                                                                 |
# | NumberOfDeviceRegistered    | 0.07                   | Pengguna dengan lebih banyak perangkat sedikit lebih berpotensi untuk churn.                                                              |
# | NumberOfAddress             | 0.04                   | Korelasi positif yang sangat kecil.                                                                                                        |
# | Gender                      | 0.03                   | Korelasi positif minor — pelanggan laki-laki sedikit lebih cenderung churn.                                                               |
# | HourSpendOnApp              | 0.02                   | Korelasi positif sangat lemah — penggunaan aplikasi hampir tidak berpengaruh.                                                             |
# | PreferredPaymentMode        | 0.002                  | Hampir tidak ada korelasi — metode pembayaran tidak memengaruhi churn.                                                                    |
# | OrderAmountHikeFromlastYear | -0.005                 | Korelasi negatif sangat lemah — pertumbuhan nilai pesanan hampir tidak berdampak pada churn.                                             |
# | CouponUsed                  | -0.03                  | Korelasi negatif ringan — penggunaan kupon yang lebih tinggi sedikit menurunkan kemungkinan churn.                                       |
# | PreferredLoginDevice        | -0.05                  | Korelasi negatif minor — pengguna pada perangkat tertentu sedikit lebih kecil kemungkinannya untuk churn.                                |
# | OrderCount                  | -0.056                 | Korelasi negatif ringan — frekuensi pemesanan yang lebih tinggi sedikit mengurangi churn.                                                 |
# | CashbackAmount              | -0.13                  | Korelasi negatif sedang — cashback yang lebih tinggi dapat menurunkan kemungkinan churn.                                                 |
# | DaySinceLastOrder           | -0.16                  | Korelasi negatif sedang — pelanggan yang baru saja melakukan pemesanan lebih kecil kemungkinannya untuk churn.                           |
# | Tenure                      | -0.34                  | **Korelasi negatif terkuat** — pelanggan dengan masa berlangganan lebih lama jauh lebih kecil kemungkinannya untuk churn.                 |

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(df, features=None):
    if features is None:
        # Select numeric features only
        features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

    X = df[features].copy()

    vif_data = []
    for i in range(X.shape[1]):
        vif_value = variance_inflation_factor(X.values, i)
        vif_data.append({'Feature': X.columns[i], 'VIF': round(vif_value, 2)})

    vif_df = pd.DataFrame(vif_data).sort_values(by='VIF', ascending=False).reset_index(drop=True)
    return vif_df

# %%
vif_table = calculate_vif(df)
vif_table
# Out:
#                         Feature    VIF
# 0                CashbackAmount  39.83
# 1      NumberOfDeviceRegistered  25.81
# 2                HourSpendOnApp  22.71
# 3   OrderAmountHikeFromlastYear  18.84
# 4              PreferedOrderCat   6.35
# 5                    OrderCount   6.21
# 6             SatisfactionScore   5.85
# 7               WarehouseToHome   4.74
# 8                      CityTier   4.67
# 9                    CouponUsed   4.41
# 10              NumberOfAddress   4.32
# 11         PreferredPaymentMode   4.24
# 12                MaritalStatus   4.10
# 13            DaySinceLastOrder   3.55
# 14         PreferredLoginDevice   3.43
# 15                       Tenure   3.36
# 16                       Gender   2.50
# 17                        Churn   1.58
# 18                     Complain   1.52

# %% [markdown]
# | Feature                     | VIF   | Insight                                                                                                      |
# | --------------------------- | ----- | ------------------------------------------------------------------------------------------------------------ |
# | CashbackAmount              | 39.83 | **Multikolinearitas sangat tinggi** — sangat berkorelasi dengan fitur lain, sehingga perlu dipertimbangkan untuk dihapus atau digabung. |
# | NumberOfDeviceRegistered    | 25.81 | Korelasi sangat tinggi — dapat menyebabkan ketidakstabilan pada model regresi.                              |
# | HourSpendOnApp              | 22.71 | Korelasi tinggi — disarankan untuk mempertimbangkan reduksi fitur.                                           |
# | OrderAmountHikeFromlastYear | 18.84 | Korelasi tinggi — berpotensi menyebabkan masalah multikolinearitas.                                         |
# | PreferedOrderCat            | 6.35  | Korelasi sedang — masih dapat diterima namun perlu dipantau.                                                |
# | OrderCount                  | 6.21  | Korelasi sedang — kemungkinan berkorelasi dengan OrderAmountHike atau fitur pembelian lainnya.             |
# | SatisfactionScore           | 5.85  | Korelasi sedang — berada di batas ambang.                                                                   |
# | WarehouseToHome             | 4.74  | Rendah hingga sedang — secara umum masih dapat diterima.                                                    |
# | CityTier                    | 4.67  | Rendah hingga sedang — dapat diterima.                                                                      |
# | CouponUsed                  | 4.41  | Rendah hingga sedang — dapat diterima.                                                                      |
# | NumberOfAddress             | 4.32  | Rendah hingga sedang — dapat diterima.                                                                      |
# | PreferredPaymentMode        | 4.24  | Rendah hingga sedang — dapat diterima.                                                                      |
# | MaritalStatus               | 4.10  | Rendah hingga sedang — dapat diterima.                                                                      |
# | DaySinceLastOrder           | 3.55  | Korelasi rendah — aman digunakan.                                                                           |
# | PreferredLoginDevice        | 3.43  | Korelasi rendah — aman digunakan.                                                                           |
# | Tenure                      | 3.36  | Korelasi rendah — aman digunakan.                                                                           |
# | Gender                      | 2.50  | Korelasi rendah — aman digunakan.                                                                           |
# | Churn                       | 1.58  | Korelasi rendah — variabel target.                                                                          |
# | Complain                    | 1.52  | Korelasi rendah — aman digunakan.                                                                           |

# %% [markdown]
# # **SHAP (Features Selection)**
# **SHAP bersifat model-agnostic:**
#
# * Nilai SHAP mengukur kontribusi setiap fitur terhadap prediksi pada **model dan instance tertentu**, dengan tetap mempertimbangkan **interaksi antar fitur**.
#
# * Meskipun dua fitur memiliki korelasi yang tinggi, **SHAP akan membagi kontribusinya secara adil** sesuai dengan peran masing-masing fitur dalam prediksi.
#
# * Masalah korelasi menjadi **kurang signifikan pada model berbasis tree**:
#
# * SHAP sering digunakan bersama **XGBoost, LightGBM, atau Random Forest**, yang **tidak sensitif terhadap multikolinearitas** seperti pada model linear.
#
# * Oleh karena itu, **menghapus fitur hanya berdasarkan nilai VIF tidaklah wajib** ketika analisis berfokus pada SHAP.
#
# **Interpretability (Kemudahan Interpretasi):**
#
# * SHAP mampu menyoroti **fitur mana yang benar-benar mendorong prediksi**, meskipun fitur-fitur tersebut saling berkorelasi.
#
# * Jika dua fitur sangat berkorelasi tetapi salah satunya lebih prediktif, **SHAP akan menunjukkannya dengan jelas**, sehingga membantu Anda memfokuskan analisis pada variabel yang paling bermakna.

# %%
# !pip install shap

# %%
X = df.drop('Churn', axis=1)
y = df['Churn']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)


import xgboost as xgb
import shap

# Train an XGBoost model
model = xgb.XGBClassifier()
model.fit(X_train, y_train)

# Explain the model's predictions using SHAP
explainer = shap.Explainer(model)
shap_values = explainer.shap_values(X_test)

# Plot the SHAP values
shap.summary_plot(shap_values, X_test)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
def shap_feature_importance(model, X, top_n=15, plot=True):
    explainer = shap.Explainer(model, X)
    shap_values = explainer(X)

    # Aggregate absolute SHAP values
    shap_abs = np.abs(shap_values.values).mean(axis=0)

    # Create feature importance dataframe
    feature_importance = pd.DataFrame({
        'Feature': X.columns,
        'SHAP Importance': shap_abs
    }).sort_values(by='SHAP Importance', ascending=False)

    # Select top N features
    top_features = feature_importance.head(top_n)

    if plot:
        plt.figure(figsize=(10, 6))
        shap.summary_plot(shap_values, X, plot_type='bar', max_display=top_n, show=True)

    return top_features

# %%
top_features = shap_feature_importance(model, X, top_n=15, plot=True)
print(top_features)

# %% [markdown]
# | Rank | Feature                     | SHAP Importance | Insight                                                                                                                      |
# | ---- | --------------------------- | --------------- | ---------------------------------------------------------------------------------------------------------------------------- |
# | 1    | Tenure                      | 2.03            | **Tenure** pelanggan merupakan prediktor paling penting — pelanggan dengan masa berlangganan lebih lama cenderung tidak churn. |
# | 2    | Complain                    | 0.997           | Pelanggan yang **pernah mengajukan komplain** memiliki probabilitas churn yang lebih tinggi, sehingga riwayat komplain menjadi faktor kunci. |
# | 3    | NumberOfAddress             | 0.834           | Jumlah alamat yang lebih banyak dapat menunjukkan keterlibatan, namun juga bisa berkaitan dengan churn jika tidak terkelola dengan baik atau tidak konsisten. |
# | 4    | CashbackAmount              | 0.661           | Rata-rata cashback memiliki pengaruh terhadap churn — cashback yang lebih tinggi dapat membantu menurunkan churn.          |
# | 5    | WarehouseToHome             | 0.560           | Jarak dari gudang memengaruhi churn — jarak pengiriman yang lebih jauh dapat meningkatkan kemungkinan churn.               |
# | 6    | SatisfactionScore           | 0.469           | Skor kepuasan yang lebih tinggi berkorelasi dengan kemungkinan churn yang lebih rendah.                                     |
# | 7    | MaritalStatus               | 0.433           | Pelanggan dengan status single atau divorced menunjukkan kecenderungan churn yang sedikit lebih tinggi dibandingkan married. |
# | 8    | PreferedOrderCat            | 0.430           | Kategori pesanan yang disukai (misalnya Mobile, Laptop) memengaruhi churn, karena beberapa kategori memiliki tingkat churn yang lebih tinggi. |
# | 9    | DaySinceLastOrder           | 0.427           | Jeda waktu yang lebih lama sejak pesanan terakhir menunjukkan kemungkinan churn yang lebih tinggi.                          |
# | 10   | CityTier                    | 0.409           | Pelanggan di kota kecil atau wilayah rural cenderung memiliki risiko churn yang sedikit lebih tinggi.                      |
# | 11   | OrderAmountHikeFromlastYear | 0.297           | Perubahan nilai pesanan dari tahun sebelumnya memiliki pengaruh yang relatif kecil.                                        |
# | 12   | OrderCount                  | 0.293           | Jumlah pesanan berkontribusi secara moderat dalam prediksi churn.                                                           |
# | 13   | PreferredPaymentMode        | 0.262           | Metode pembayaran sedikit memengaruhi churn — beberapa metode berkaitan dengan tingkat churn yang lebih tinggi.            |
# | 14   | Gender                      | 0.223           | Pelanggan laki-laki menunjukkan kecenderungan churn yang sedikit lebih tinggi dibandingkan pelanggan perempuan.            |
# | 15   | PreferredLoginDevice        | 0.174           | Preferensi perangkat memiliki pengaruh yang sangat kecil terhadap prediksi churn.                                          |

# %%
df = df[top_features['Feature'].tolist()+['Churn']]
df.head()

# %%
# lets get the independent features and dependent feature
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %% [markdown]
# ### Normalize the Dataset

# %%
# Feature scaling marks the end of the data preprocessing in Machine Learning.
# It is a method to standardize the independent variables of a dataset within a specific range.
# In other words, feature scaling limits the range of variables so that you can compare them on common grounds.
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
X = std.fit_transform(X)

# %% [markdown]
# ### Split the Data

# %%
def splitting_dataset(X, y, test_size=0.20, classifcation=False):
    from sklearn.model_selection import train_test_split

    assert X.shape[0] == y.shape[0], "Number of samples in X and y should be the same."


    if classifcation:
      X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0, stratify=y)
    else:
      X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=0)

    # Check the shape of training and testing sets
    print("Training shape:", X_train.shape)
    print("Testing shape:", X_test.shape)

    return X_train, X_test, y_train, y_test

# %%
# lets split the dataset (75:25)
X_train, X_test, y_train, y_test = splitting_dataset(X, y , test_size=0.2, classifcation=True)

# %%
# get the value counts
y_train_series = pd.Series(y_train).astype(int)
y_test_series = pd.Series(y_test).astype(int)

Classes = ['Not Churned', 'Churned']

class_mapping = {index: class_name for index, class_name in enumerate(Classes)}

train_value_counts = y_train_series.map(class_mapping).value_counts()
test_value_counts = y_test_series.map(class_mapping).value_counts()


# Create a Pandas DataFrame
df = pd.DataFrame({'Train': train_value_counts, 'Test': test_value_counts})


fig, ax = plt.subplots(figsize=(10, 6))

# Create a grouped bar plot
ax = df.plot.bar(width=0.9, ax=ax)

for p in ax.containers:
    ax.bar_label(p, label_type='edge', padding=1)

# Set the labels and title
ax.set_xlabel('Class')
ax.set_ylabel('Count')
ax.set_title('Data Splition Distribution')

plt.savefig("train_test_val.png", bbox_inches='tight')
# Show the plot
plt.show()

# %% [markdown]
# # **Model Building**

# %%
from tqdm.auto import tqdm

# Import classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_validate

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import time
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import LinearSVC
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# **Penanganan Target Tidak Seimbang (Imbalanced) pada Prediksi Churn**
#
# * Dalam dataset ini, variabel target **Churn** sangat tidak seimbang: sekitar **17% pelanggan mengalami churn**, sementara **83% pelanggan tetap bertahan**. Ketidakseimbangan ini menimbulkan tantangan dalam evaluasi model klasifikasi, karena metrik tradisional seperti **accuracy** dapat menyesatkan.
#   Sebagai contoh, model yang selalu memprediksi **“Not Churned”** tetap dapat memperoleh accuracy tinggi, meskipun gagal mendeteksi pelanggan yang benar-benar churn.
#
# **Metrik Evaluasi untuk Data Tidak Seimbang**
#
# **ROC-AUC (Receiver Operating Characteristic – Area Under Curve):**
#
# * Mengukur seberapa baik model membedakan antara pelanggan yang churn dan tidak churn pada berbagai threshold.
#
# * Namun, **ROC-AUC dapat terlihat terlalu optimistis pada dataset yang sangat imbalanced**, karena jumlah sampel kelas mayoritas yang besar dapat menaikkan nilai metrik secara artifisial.
#
# **Precision, Recall, dan F1 Score:**
#
# * **Precision** mengukur proporsi pelanggan yang diprediksi churn dan benar-benar churn.
#
# * **Recall** mengukur proporsi pelanggan churn yang berhasil diidentifikasi dengan benar oleh model.
#
# * **F1 Score** menggabungkan precision dan recall ke dalam satu metrik, sehingga memberikan ukuran performa yang lebih seimbang ketika data tidak seimbang.
#
# * Penggunaan **F1 Score** membantu menyeimbangkan antara:
#   * **False Positive** (memprediksi churn padahal pelanggan tidak churn)
#   * **False Negative** (gagal memprediksi pelanggan yang benar-benar churn)
#
#   Hal ini sangat penting untuk menargetkan **strategi retensi pelanggan** secara efektif.
#
# **Precision–Recall AUC (PR-AUC):**
#
# * Merangkum kurva Precision–Recall dan **sangat berguna untuk dataset yang tidak seimbang**.
#
# * **Berfokus pada kemampuan model dalam mengidentifikasi kelas minoritas (pelanggan churn)** tanpa terlalu dipengaruhi oleh dominasi kelas mayoritas.

# %%
from sklearn.metrics import roc_auc_score, roc_curve, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import cross_val_score, StratifiedKFold

def results(model, X_train, y_pred, y_test, y_pred_train, y_train, classes, multi_class=False, show_cm=False, show_roc=False):
    if multi_class:
        accuracy = round(accuracy_score(y_pred, y_test) * 100, 2)
        train_accuracy = round(accuracy_score(y_pred_train, y_train) * 100, 2)
        precision = round(precision_score(y_pred, y_test, average='macro') * 100, 2)
        recall = round(recall_score(y_pred, y_test, average='macro') * 100, 2)
        f1_scr = round(f1_score(y_pred, y_test, average='macro') * 100, 2)
    else:
        accuracy = round(accuracy_score(y_pred, y_test) * 100, 2)
        train_accuracy = round(accuracy_score(y_pred_train, y_train) * 100, 2)
        precision = round(precision_score(y_pred, y_test) * 100, 2)
        recall = round(recall_score(y_pred, y_test) * 100, 2)
        f1_scr = round(f1_score(y_pred, y_test) * 100, 2)

    # Calculate AUC-ROC score
    auc_roc_score = roc_auc_score(y_test, y_pred)

    # Calculate AUC-ROC score using k-fold cross-validation
    kfold = StratifiedKFold(n_splits=5)
    auc_scores = cross_val_score(model, X_train, y_train, cv=kfold, scoring='roc_auc')




    print("\nTraining Accuracy: {}%".format(train_accuracy))
    print("Testing Accuracy: {}%".format(accuracy))
    print("Precision: {}%".format(precision))
    print("Recall: {}%".format(recall))
    print("F1-Score: {}%".format(f1_scr))
    # print("AUC-ROC Score: {}".format(auc_roc_score))
    # Print mean AUC-ROC score for all folds
    print("Mean AUC-ROC Score (5-fold cross-validation):", np.mean(auc_scores))
    print()

    if show_cm:
        print("Classification Report:")
        print(classification_report(y_pred, y_test, target_names=classes))
        print()
        print("Confusion Matrix:")
        fig, ax = plt.subplots(figsize=(7, 5))
        ConfusionMatrixDisplay.from_predictions(y_pred, y_test,
                                                  ax=ax,
                                                  display_labels=classes,
                                                  xticks_rotation='vertical')
        plt.show()

    if show_roc:
        # Plot ROC curve
        fpr, tpr, _ = roc_curve(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.2f)' % auc_roc_score)
        plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('Receiver Operating Characteristic (ROC) Curve')
        plt.legend(loc='lower right')
        plt.show()

    return {
        'Model': model.__class__.__name__,
        'Training Accuracy': train_accuracy,
        'Testing Accuracy': accuracy,
        'Precision': precision,
        'Recall': recall,
        'F1': f1_scr,
        # 'AUC-ROC Score': auc_roc_score,
        'KFold AUC-ROC Score': np.mean(auc_scores)
    }

# %%
def train_model(model,X_train,y_train,X_test,y_test, labelEncoder, multi_class=None, show_cm = False, show_roc=False):
    # Record the start time
    start_time = time.time()

    # Fit the model on the training data
    model.fit(X_train, y_train)

    # Record the end time
    end_time = time.time()

    # Compute the training time in seconds
    training_time = end_time - start_time
    print(f"Training time: {training_time:.3f} seconds")

    # predict the model on testing data
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)


    # get results
    RESULTS_LR = results(model,X_train, y_pred, y_test,y_pred_train, y_train, labelEncoder, multi_class, show_cm, show_roc)

    # Add the training time to RESULTS_LR
    RESULTS_LR['Training time (s)'] = training_time

    return RESULTS_LR, model

# %%
def get_model_results(res):
  # Convert the dictionary to a DataFrame
  return pd.DataFrame.from_dict([res]).set_index('Model')

# %%
MODELS = {
    'RandomForestClassifier': RandomForestClassifier(class_weight='balanced'),
    'LogisticRegression': LogisticRegression(class_weight='balanced'),
    'GaussianNB': GaussianNB(),
    'SVC': SVC(class_weight='balanced', probability=True),
    'DecisionTreeClassifier': DecisionTreeClassifier(class_weight='balanced'),
    'AdaBoostClassifier': AdaBoostClassifier(),
    'GradientBoostingClassifier': GradientBoostingClassifier(),
    'ExtraTreesClassifier': ExtraTreesClassifier(class_weight='balanced'),
    'BaggingClassifier': BaggingClassifier(),
    'KNeighborsClassifier': KNeighborsClassifier(),
    'MLPClassifier': MLPClassifier(),
    'SGDClassifier': SGDClassifier(class_weight='balanced'),
    'XGBClassifier': XGBClassifier(),
    'LGBMClassifier': LGBMClassifier(force_col_wise=True, class_weight='balanced'),
    'CatBoostClassifier': CatBoostClassifier(silent=True),
}

# %%
RES = []

for model_name, model in tqdm(MODELS.items(), desc=f'Model Training'):
  print("#"*100)
  print(f"\t\t\t\t {model_name}")
  print("#"*100)
  res, dt = train_model(model,X_train,y_train,X_test,y_test,  Classes, multi_class=False, show_cm=True, show_roc=True)
  df_results_dt = get_model_results(res)
  RES.append(df_results_dt)

# %%
df_all_models = pd.concat(RES).sort_values(by='KFold AUC-ROC Score', ascending=False)
final_res = df_all_models.reset_index()
print(tabulate(final_res, headers = 'keys', tablefmt = 'psql'))

# %% [markdown]
# | Model                      | Testing Accuracy (%) | Precision (%) | Recall (%) | F1 Score (%) | KFold AUC-ROC | Insight                                                                 |
# | -------------------------- | -------------------- | ------------- | ---------- | ------------ | ------------- | ----------------------------------------------------------------------- |
# | ExtraTreesClassifier       | 98.31                | 91.58         | 98.31      | 94.82        | 0.996         | Keseimbangan terbaik antara precision dan recall; sangat baik menangani data tidak seimbang |
# | RandomForestClassifier     | 97.78                | 91.05         | 95.58      | 93.26        | 0.987         | Performa ensemble yang kuat, recall sedikit lebih rendah dibanding ExtraTrees |
# | CatBoostClassifier         | 95.65                | 83.16         | 90.29      | 86.58        | 0.983         | Sangat baik dalam menangani fitur kategorikal; waktu training sedikit lebih lambat |
# | XGBClassifier              | 97.34                | 92.11         | 92.11      | 92.11        | 0.981         | Training cepat dengan performa yang seimbang |
# | LGBMClassifier             | 94.58                | 94.74         | 77.92      | 85.51        | 0.979         | Precision tinggi namun recall rendah; berpotensi melewatkan pelanggan churn |
# | BaggingClassifier          | 95.56                | 81.58         | 91.18      | 86.11        | 0.970         | Recall baik namun precision sedikit lebih rendah |
# | KNeighborsClassifier       | 93.34                | 71.05         | 87.10      | 78.26        | 0.953         | Precision sedang; cukup banyak false positive |
# | SVC                        | 88.37                | 93.68         | 59.93      | 73.10        | 0.953         | Sangat presisi tetapi banyak melewatkan kasus churn (recall rendah) |
# | GradientBoostingClassifier | 90.94                | 65.26         | 77.50      | 70.86        | 0.936         | Precision rendah; F1 sedang, training relatif lebih lambat |
# | MLPClassifier              | 93.87                | 74.74         | 87.12      | 80.45        | 0.934         | Performa cukup seimbang; training sedikit lebih lambat |
# | AdaBoostClassifier         | 88.54                | 54.21         | 71.03      | 61.49        | 0.905         | Precision dan recall rendah; kurang optimal untuk data tidak seimbang |
# | DecisionTreeClassifier     | 96.89                | 91.58         | 90.16      | 90.86        | 0.897         | Akurasi tinggi tetapi rentan terhadap overfitting |
# | LogisticRegression         | 78.51                | 77.37         | 42.49      | 54.85        | 0.861         | Recall buruk; banyak pelanggan churn yang tidak terdeteksi |
# | GaussianNB                 | 85.70                | 51.05         | 58.79      | 54.65        | 0.823         | Performa rendah; kurang cocok untuk dataset tidak seimbang |
# | SGDClassifier              | 76.47                | 73.68         | 39.44      | 51.38        | 0.812         | Performa lemah; gagal mendeteksi banyak pelanggan churn |

# %% [markdown]
# ## **ROC Curves**

# %%
def plot_roc_comparison(models_dict, X_test, y_test):
    plt.figure(figsize=(12, 8))

    for name, model in models_dict.items():
        # Check if model supports predict_proba
        if hasattr(model, "predict_proba"):
            y_pred_proba = model.predict_proba(X_test)[:, 1]
        # If not, use decision_function (for SVM, etc.)
        elif hasattr(model, "decision_function"):
            y_pred_proba = model.decision_function(X_test)
        else:
            raise ValueError(f"Model {name} does not support probability prediction or decision function.")

        # Compute ROC curve and AUC
        fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
        auc_score = roc_auc_score(y_test, y_pred_proba)

        # Plot ROC curve
        plt.plot(fpr, tpr, linewidth=2, label=f"{name} (AUC={auc_score:.3f})")

    # Plot diagonal line for random classifier
    plt.plot([0, 1], [0, 1], 'k--', linewidth=1)

    # Titles and labels
    plt.title("ROC Curve Comparison of Models", fontsize=16, fontweight='bold')
    plt.xlabel("False Positive Rate (FPR)", fontsize=14)
    plt.ylabel("True Positive Rate (TPR)", fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.6)

    # Legend
    plt.legend(loc="lower right", fontsize=12)
    plt.tight_layout()
    plt.show()


# Example usage:
plot_roc_comparison(MODELS, X_test, y_test)

# %%
model_res = final_res.reset_index()
# Find the model
best_model = model_res.loc[model_res['KFold AUC-ROC Score'].idxmax()]

print("Best Model (highest AUC-ROC Score):")
print(best_model)

# %%
model_name = best_model['Model']
model = MODELS[model_name]
res, dt = train_model(model,X_train,y_train,X_test,y_test,  Classes, multi_class=False, show_cm=True, show_roc=True)
df_results_dt = get_model_results(res)
df_results_dt

# %% [markdown]
# ### Save & Load the Model

# %%
import pickle

# --- Save the model ---
def save_model(model, filename):
    """
    Save a trained model to a pickle file
    """
    with open(filename, 'wb') as file:
        pickle.dump(model, file)
    print(f"Model saved to {filename}")

# --- Load the model ---
def load_model(filename):
    """
    Load a model from a pickle file
    """
    with open(filename, 'rb') as file:
        model = pickle.load(file)
    print(f"Model loaded from {filename}")
    return model


# Save the best model
save_model(model, 'best_model.pkl')

# Load the model later
loaded_model = load_model('best_model.pkl')

# Predict using the loaded model
y_pred = loaded_model.predict(X_test)
y_pred_proba = loaded_model.predict_proba(X_test)[:, 1]  # if you want probabilities

# Optional: show first 10 predictions
print("Predictions:", y_pred[:10])
print("Predicted Probabilities:", y_pred_proba[:10])
